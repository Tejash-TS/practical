# %%
# Assignment 11: Multiclass Classification using Deep Neural Networks
# OCR Letter Recognition using Deep Neural Network

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %%
# Load Dataset
# Kaggle Dataset File:
# letter-recognition.csv

data = pd.read_csv("letter-recognition.csv")

# Display First 5 Rows
print("\nDataset Preview:\n")
print(data.head())
# Out:
# Dataset Preview:
#
#   letter  xbox   ybox   width   height  onpix   xbar   ybar   x2bar  y2bar   \
# 0      T      2      8       3       5       1      8     13      0       6
# 1      I      5     12       3       7       2     10      5      5       4
# 2      D      4     11       6       8       6     10      6      2       6
# 3      N      7     11       6       6       3      5      9      4       6
# 4      G      2      1       3       1       1      8      6      6       6
#
#    xybar   x2ybar  xy2bar  xedge   xedgey  yedge   yedgex
# 0       6      10       8       0       8       0       8
# 1      13       3       9       2       8       4      10
# 2      10       3       7       3       7       3       9
# 3       4       4      10       6      10       2       8
# 4       6       5       9       1       7       5      10

# %%
X = data.iloc[:, 1:].values
y = data.iloc[:, 0].values

# Encode Labels
encoder = LabelEncoder()

y_encoded = encoder.fit_transform(y)

# Convert Labels to One-Hot Encoding
y_categorical = to_categorical(y_encoded)

# %%
# Feature Scaling
scaler = StandardScaler()

X = scaler.fit_transform(X)

# %%
# Split Dataset
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y_categorical,
    test_size=0.2,
    random_state=42
)

# %%
# Build Deep Neural Network
model = Sequential()

# Input + Hidden Layers
model.add(Dense(128, activation='relu', input_shape=(16,)))
model.add(Dropout(0.3))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(32, activation='relu'))
# Out:
# C:\Users\np200\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Output Layer (26 Alphabets)
model.add(Dense(26, activation='softmax'))

# Compile Model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Model Summary
print("\nModel Summary:\n")
model.summary()
# Out:
# Model Summary:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │           2,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 26)                  │             858 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13,370 (52.23 KB)
#  Trainable params: 13,370 (52.23 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train Model
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3622 - loss: 2.1274 - val_accuracy: 0.6628 - val_loss: 1.1577
# Epoch 2/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6068 - loss: 1.2470 - val_accuracy: 0.7434 - val_loss: 0.8794
# Epoch 3/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6698 - loss: 1.0470 - val_accuracy: 0.7706 - val_loss: 0.7695
# Epoch 4/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7059 - loss: 0.9322 - val_accuracy: 0.7969 - val_loss: 0.6905
# Epoch 5/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7247 - loss: 0.8678 - val_accuracy: 0.8150 - val_loss: 0.6327
# Epoch 6/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7396 - loss: 0.8087 - val_accuracy: 0.8306 - val_loss: 0.5755
# Epoch 7/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7569 - loss: 0.7667 - val_accuracy: 0.8447 - val_loss: 0.5363
# Epoch 8/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7713 - loss: 0.7234 - val_accuracy: 0.8575 - val_loss: 0.5037
# Epoch 9/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7768 - loss: 0.6995 - val_accuracy: 0.8575 - val_loss: 0.4887
# Epoch 10/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7864 - loss: 0.6740 - val_accuracy: 0.8631 - val_loss: 0.4683
# Epoch 11/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7931 - loss: 0.6436 - val_accuracy: 0.8722 - val_loss: 0.4477
# Epoch 12/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8023 - loss: 0.6139 - val_accuracy: 0.8756 - val_loss: 0.4229
# Epoch 13/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8002 - loss: 0.6178 - val_accuracy: 0.8778 - val_loss: 0.4106
# Epoch 14/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8109 - loss: 0.5920 - val_accuracy: 0.8891 - val_loss: 0.3862
# Epoch 15/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8152 - loss: 0.5769 - val_accuracy: 0.8844 - val_loss: 0.3843
# Epoch 16/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8208 - loss: 0.5598 - val_accuracy: 0.8931 - val_loss: 0.3612
# Epoch 17/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8226 - loss: 0.5447 - val_accuracy: 0.8959 - val_loss: 0.3535
# Epoch 18/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8295 - loss: 0.5267 - val_accuracy: 0.8959 - val_loss: 0.3503
# Epoch 19/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8264 - loss: 0.5428 - val_accuracy: 0.9025 - val_loss: 0.3366
# Epoch 20/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8342 - loss: 0.5166 - val_accuracy: 0.8956 - val_loss: 0.3360

# %%
# Evaluate Model
loss, accuracy = model.evaluate(X_test, y_test)

print("\nTest Accuracy:", accuracy)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9032 - loss: 0.3150
#
# Test Accuracy: 0.903249979019165

# %%
# Predict Sample
prediction = model.predict(X_test[:1])

predicted_class = np.argmax(prediction)

predicted_letter = encoder.inverse_transform([predicted_class])[0]

print("\nPredicted Letter:", predicted_letter)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
#
# Predicted Letter: X

# %%
# Display Actual Letter
actual_class = np.argmax(y_test[0])

actual_letter = encoder.inverse_transform([actual_class])[0]

print("Actual Letter:", actual_letter)
# Out:
# Actual Letter: T
